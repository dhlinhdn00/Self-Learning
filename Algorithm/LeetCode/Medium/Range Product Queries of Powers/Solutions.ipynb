# %% [markdown]
# # **SOLUTION**

# %%
class Solution(object):
    def productQueries(self, n, queries):
        """
        :type n: int
        :type queries: List[List[int]]
        :rtype: List[int]
        """

# %% [markdown]
# # **DRAFT**

# %%
n = 15
def _convertSumOfPowers(n):

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

def run_test_case(case_number, input_n, input_queries, expected):
    result = solution.productQueries(input_n, input_queries)
    status = "PASSED" if result == expected else "FAILED"
    print(f"Case {case_number} - n: {input_n}, queries: {input_queries}, Output: {result}, Expected: {expected}, Status: {status}")

test_cases = [
    (1, 15, [[0,1],[2,2],[0,3]], [2,4,64]),
    (2, 2, [[0,0]], [2])
]

for case_number, input_n, input_queries, expected in test_cases:
    run_test_case(case_number, input_n, input_queries, expected)
# Out:
# Case 1 - n: 15, queries: [[0, 1], [2, 2], [0, 3]], Output: None, Expected: [2, 4, 64], Status: FAILED
# Case 2 - n: 2, queries: [[0, 0]], Output: None, Expected: [2], Status: FAILED
