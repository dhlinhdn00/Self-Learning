# %% [markdown]
# # **SOLUTION**

# %%
class Solution(object):
    def findFinalValue(self, nums, original):
        """
        :type nums: List[int]
        :type original: int
        :rtype: int
        """
        return self.solverNaive(nums, original)
    
    def solverNaive(self, nums, original):
        
        while original in nums:
            original *= 2

        return original

# %% [markdown]
# # **DRAFT**

# %%
nums = [5,3,6,1,12]
original = 3

while original in nums:
    original *= 2
    
original
# Out:
# 24

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

# def extraCondition(result, expected):
#     pass


def run_test_case(case_number, input_nums, input_original, expected):
    result = solution.findFinalValue(input_nums, input_original)
    status = "PASSED" if result == expected else "FAILED"
    # status = "PASSED" if extraCondition(result, expected) else "FAILED"
    print(f"Case {case_number} - (nums, original): {(input_nums, input_original)}, Output: {result}, Expected: {expected}, Status: {status}")

test_cases = [
    (1, [5,3,6,1,12], 3, 24),
    (2, [2,7,9], 4, 4),
]

for case_number, input_nums, input_original, expected in test_cases:
    run_test_case(case_number, input_nums, input_original, expected)
# Out:
# Case 1 - (nums, original): ([5, 3, 6, 1, 12], 3), Output: 24, Expected: 24, Status: PASSED
# Case 2 - (nums, original): ([2, 7, 9], 4), Output: 4, Expected: 4, Status: PASSED
