# %% [markdown]
# # **SOLUTION**

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def createLinkedList(arr):
    if not arr: return None
    head = ListNode(arr[0])
    curr = head
    for val in arr[1:]:
        curr.next = ListNode(val)
        curr = curr.next
    return head 

class Solution(object):
    def pairSum(self, head):
        """
        :type head: Optional[ListNode]
        :rtype: int
        """
        head = createLinkedList(head)
        return self.solverSlowFast(head)
    
    def solverSlowFast(self, head):
        slow, fast = head, head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next

        prev = None
        curr = slow
        while curr:
            nextNode = curr.next
            curr.next = prev
            prev = curr
            curr = nextNode
        
        maxSum = 0
        firstHalf = head
        secondHalf = prev

        while secondHalf:
            currentSum = firstHalf.val + secondHalf.val
            maxSum = max(maxSum, currentSum)

            firstHalf = firstHalf.next
            secondHalf = secondHalf.next

        return maxSum

# %% [markdown]
# # **DRAFT**

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

# def extraCondition(result, expected):
#     pass


def run_test_case(case_number, input_head, expected):
    result = solution.pairSum(input_head)
    status = "PASSED" if result == expected else "FAILED"
    # status = "PASSED" if extraCondition(result, expected) else "FAILED"
    print(f"Case {case_number} - (head): {(input_head)}, Output: {result}, Expected: {expected}, Status: {status}")

test_cases = [
    (1, [5,4,2,1], 6),
    (2, [4,2,2,3], 7),
    (3, [1,100000], 100001)
]

for case_number, input_head, expected in test_cases:
    run_test_case(case_number, input_head, expected)
# Out:
# Case 1 - (head): [5, 4, 2, 1], Output: 6, Expected: 6, Status: PASSED
# Case 2 - (head): [4, 2, 2, 3], Output: 7, Expected: 7, Status: PASSED
# Case 3 - (head): [1, 100000], Output: 100001, Expected: 100001, Status: PASSED
