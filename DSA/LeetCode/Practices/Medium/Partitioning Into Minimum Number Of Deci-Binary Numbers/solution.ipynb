# %% [markdown]
# # **SOLUTION**

# %%
class Solution(object):
    def minPartitions(self, n):
        """
        :type n: str
        :rtype: int
        """
        return self.solverNaive(n)

    def solverNaive(self, n):
        return int(max(n))

# %% [markdown]
# # **DRAFT**

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

# def extraCondition(result, expected):
#     pass


def run_test_case(case_number, input_n, expected):
    result = solution.minPartitions(input_n)
    status = "PASSED" if result == expected else "FAILED"
    # status = "PASSED" if extraCondition(result, expected) else "FAILED"
    print(f"Case {case_number} - (n): {(input_n)}, Output: {result}, Expected: {expected}, Status: {status}")

test_cases = [
    (1, "32", 3),
    (2, "82734", 8),
    (3, "27346209830709182346", 9),
]

for case_number, input_n, expected in test_cases:
    run_test_case(case_number, input_n, expected)
# Out:
# Case 1 - (n): 32, Output: 3, Expected: 3, Status: PASSED
# Case 2 - (n): 82734, Output: 8, Expected: 8, Status: PASSED
# Case 3 - (n): 27346209830709182346, Output: 9, Expected: 9, Status: PASSED
