# %% [markdown]
# # **SOLUTION**

# %%
class Solution(object):
    def maxOperations(self, s):
        """
        :type s: str
        :rtype: int
        """
        return self.solverNaive(s)
    
    def solverNaive(self, s):
        count_1 = []
        prev_count = 0
        check_1 = False
        count = 0
        for c in s:
            if c == "1":
                check_1 = True
                count += 1
            else:
                check_l = False
                if count != 0:
                    count_1.append(count + prev_count)
                    prev_count += count
                count = 0
        return sum(count_1)

# %% [markdown]
# # **DRAFT**

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

# def extraCondition(result, expected):
#     pass

def run_test_case(case_number, input_s, expected):
    result = solution.maxOperations(input_s)
    status = "PASSED" if result == expected else "FAILED"
    # status = "PASSED" if extraCondition(result, expected) else "FAILED"

    print(f"Case {case_number} - s: {input_s}, Output: {result}, Expected: {expected}, Status: {status}")

test_cases = [
    (1, "1001101", 4),
    (2, "00111", 0),
]

for case_number, input_s, expected in test_cases:
    run_test_case(case_number, input_s, expected)
# Out:
# Case 1 - s: 1001101, Output: 4, Expected: 4, Status: PASSED
# Case 2 - s: 00111, Output: 0, Expected: 0, Status: PASSED
