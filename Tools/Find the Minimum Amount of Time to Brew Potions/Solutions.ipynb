# %% [markdown]
# # **SOLUTION**

# %%
class Solution(object):
    def minTime(self, skill, mana):
        """
        :type skill: List[int]
        :type mana: List[int]
        :rtype: int
        """

# %% [markdown]
# # **DRAFT**

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

def run_test_case(case_number, input_skill, input_mana, expected):
    result = solution.minTime(input_skill, input_mana)
    status = "PASSED" if result == expected else "FAILED"
    print(f"Case {case_number} - (skill, mana): ({input_skill, input_mana}), Output: {result}, Expected: {expected}, Status: {status}")
test_cases = [
    (1, [1,5,2,4], [5,1,4,2], 110),
    (2, [1,1,1], [1,1,1], 5),
    (3, [1,2,3,4], [1,2], 21)
]

for case_number, input_skill, input_mana, expected in test_cases:
    run_test_case(case_number, input_skill, input_mana, expected)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 14
#       7 test_cases = [
#       8     (1, [1,5,2,4], [5,1,4,2], 110),
#       9     (2, [1,1,1], [1,1,1], 5),
#      10     (3, [1,2,3,4], [1,2], 21)
#      11 ]
#      13 for case_number, input_skill, input_mana, expected in test_cases:
# ---> 14     run_test_case(case_number, input_skill, input_mana, expected)
#
# Cell In[4], line 4, in run_test_case(case_number, input_skill, input_mana, expected)
#       3 def run_test_case(case_number, input_skill, input_mana, expected):
# ----> 4     result = solution.successfulPairs(input_skill, input_mana)
#       5     status = "PASSED" if result == expected else "FAILED"
#       6     print(f"Case {case_number} - (skill, mana): ({input_skill, input_mana}), Output: {result}, Expected: {expected}, Status: {status}")
#
# AttributeError: 'Solution' object has no attribute 'successfulPairs'
