# %% [markdown]
# # **SOLUTION**

# %%
class Solution(object):
    def triangleNumber(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        return self.solverNaive(nums)
    
    def solverNaive(self, nums):
        nums.sort()
        n = len(nums)
        count = 0
        for k in range(n - 1, 1, -1):
            i, j = 0, k - 1
            while i < j:
                if nums[i] + nums[j] > nums[k]:
                    count += (j - i)
                    j -= 1
                else:
                    i += 1
        return count

# %% [markdown]
# # **DRAFT**

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

def run_test_case(case_number, input_nums, expected):
    result = solution.triangleNumber(input_nums)
    status = "PASSED" if result == expected else "FAILED"
    print(f"Case {case_number} - nums: {input_nums}, Output: {result}, Expected: {expected}, Status: {status}")

test_cases = [
    (1, [2,2,3,4], 3),
    (2, [4,2,3,4], 4),
]

for case_number, input_nums, expected in test_cases:
    run_test_case(case_number, input_nums, expected)
# Out:
# Case 1 - nums: [2, 2, 3, 4], Output: 3, Expected: 3, Status: PASSED
# Case 2 - nums: [2, 3, 4, 4], Output: 4, Expected: 4, Status: PASSED
