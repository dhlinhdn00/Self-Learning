# %% [markdown]
# # **SOLUTION**

# %%
from collections import deque

class Solution(object):
    def swimInWater(self, grid):
        """
        :type grid: List[List[int]]
        :rtype: int
        """

        n = len(grid)

        def canReach(t):
            if grid[0][0] > t:
                return False
            visited = [[False] * n for _ in range(n)]
            q = deque([(0, 0)])
            visited[0][0] = True
            directions = [(1,0), (0,1), (-1,0), (0,-1)]

            while q:
                x, y = q.popleft()
                if (x, y) == (n-1, n-1):
                    return True
                for dx, dy in directions:
                    nx, ny = x + dx, y + dy
                    if 0 <= nx < n and 0 <= ny < n and not visited[nx][ny] and grid[nx][ny] <= t:
                        visited[nx][ny] = True
                        q.append((nx, ny))
            return False

        # Binary search 
        left, right = max(grid[0][0], grid[-1][-1]), max(max(row) for row in grid)
        ans = right
        while left <= right:
            mid = (left + right) // 2
            if canReach(mid):
                ans = mid
                right = mid - 1
            else:
                left = mid + 1

        return ans

# %% [markdown]
# # **DRAFT**

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

def run_test_case(case_number, input_grid, expected):
    result = solution.swimInWater(input_grid)
    status = "PASSED" if result == expected else "FAILED"
    print(f"Case {case_number} - grid: {input_grid}, Output: {result}, Expected: {expected}, Status: {status}")

test_cases = [
    (1, [[0,2],[1,3]], 3),
    (2, [[0,1,2,3,4],[24,23,22,21,5],[12,13,14,15,16],[11,17,18,19,20],[10,9,8,7,6]], 16)
]

for case_number, input_grid, expected in test_cases:
    run_test_case(case_number, input_grid, expected)
# Out:
# Case 1 - grid: [[0, 2], [1, 3]], Output: 3, Expected: 3, Status: PASSED
# Case 2 - grid: [[0, 1, 2, 3, 4], [24, 23, 22, 21, 5], [12, 13, 14, 15, 16], [11, 17, 18, 19, 20], [10, 9, 8, 7, 6]], Output: 16, Expected: 16, Status: PASSED
