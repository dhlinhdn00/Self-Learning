# %% [markdown]
# # **SOLUTION**

# %%
class Solution(object):
    def finalValueAfterOperations(self, operations):
        """
        :type operations: List[str]
        :rtype: int
        """
        return self.solverNaive(operations)

    def solverNaive(self, operations):
        for i in range(len(operations)):
            state = operations[i]
            if state == "X++" or state == "++X":
                operations[i] = 1
            elif state == "X--" or state == "--X":
                operations[i] = -1

        return sum(operations)

# %% [markdown]
# # **DRAFT**

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

def run_test_case(case_number, input_operations, expected):
    result = solution.finalValueAfterOperations(input_operations)
    status = "PASSED" if result == expected else "FAILED"
    print(f"Case {case_number} - operations: {input_operations}, Output: {result}, Expected: {expected}, Status: {status}")

test_cases = [
    (1, ["--X","X++","X++"], 1),
    (2, ["++X","++X","X++"], 3),
    (3, ["X++","++X","--X","X--"], 0)
]

for case_number, input_digits, expected in test_cases:
    run_test_case(case_number, input_digits, expected)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 15
#       8 test_cases = [
#       9     (1, ["--X","X++","X++"], 1),
#      10     (2, ["++X","++X","X++"], 3),
#      11     (3, ["X++","++X","--X","X--"], 0)
#      12 ]
#      14 for case_number, input_digits, expected in test_cases:
# ---> 15     run_test_case(case_number, input_digits, expected)
#
# Cell In[2], line 4, in run_test_case(case_number, input_digits, expected)
#       3 def run_test_case(case_number, input_digits, expected):
# ----> 4     result = solution.findEvenNumbers(input_digits)
#       5     status = "PASSED" if result == expected else "FAILED"
#       6     print(f"Case {case_number} - digits: {input_digits}, Output: {result}, Expected: {expected}, Status: {status}")
#
# AttributeError: 'Solution' object has no attribute 'findEvenNumbers'
