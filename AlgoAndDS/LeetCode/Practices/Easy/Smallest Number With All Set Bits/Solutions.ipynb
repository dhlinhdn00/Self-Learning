# %% [markdown]
# # **SOLUTION**

# %%
class Solution(object):
    def smallestNumber(self, n):
        """
        :type n: int
        :rtype: int
        """
        return self.solverNaive(n)
    
    def solverNaive(self, n):
        return (1 << n.bit_length()) - 1

# %% [markdown]
# # **DRAFT**

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

def run_test_case(case_number, input_n, expected):
    result = solution.smallestNumber(input_n)
    status = "PASSED" if result == expected else "FAILED"
    print(f"Case {case_number} - n: {input_n}, Output: {result}, Expected: {expected}, Status: {status}")

test_cases = [
    (1, 5, 7),
    (2, 10, 15),
    (3, 3, 3),
]

for case_number, input_n, expected in test_cases:
    run_test_case(case_number, input_n, expected)
# Out:
# Case 1 - n: 5, Output: 7, Expected: 7, Status: PASSED
# Case 2 - n: 10, Output: 15, Expected: 15, Status: PASSED
# Case 3 - n: 3, Output: 3, Expected: 3, Status: PASSED
