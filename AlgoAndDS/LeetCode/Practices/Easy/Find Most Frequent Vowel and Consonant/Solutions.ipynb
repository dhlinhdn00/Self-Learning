# %% [markdown]
# # **SOLUTION**

# %%
class Solution(object):
    def maxFreqSum(self, s):
        """
        :type s: str
        :rtype: int
        """
        return self.solverNaive(s)
    
    def solverNaive(self, s):
        dp = [0] * 26
        for c in s:
            i = ord(c) - 97
            dp[i] += 1
        max_v = max(dp[0], dp[4], dp[8], dp[14], dp[20])
        for i in [20, 14, 8, 4, 0]:
            del dp[i]
        max_s = max(dp)
        return max_v + max_s

# %% [markdown]
# # **DRAFT**

# %%
print(ord("a") - 97)
print(ord("e") - 97)
print(ord("i") - 97)
print(ord("o") - 97)
print(ord("u") - 97)
# Out:
# 0
# 4
# 8
# 14
# 20

# %%
dp = [0] * 5
del(dp[1])
max(dp)
# Out:
# 0

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

def run_test_case(case_number, input_s, expected):
    result = solution.maxFreqSum(input_s)
    status = "PASSED" if result == expected else "FAILED"
    print(f"Case {case_number} - s: {input_s}, Output: {result}, Expected: {expected}, Status: {status}")

test_cases = [
    (1, "successes", 6),
    (2, "aeiaeia", 3)
]

for case_number, input_s, expected in test_cases:
    run_test_case(case_number, input_s, expected)
# Out:
# Case 1 - s: successes, Output: 6, Expected: 6, Status: PASSED
# Case 2 - s: aeiaeia, Output: 3, Expected: 3, Status: PASSED
