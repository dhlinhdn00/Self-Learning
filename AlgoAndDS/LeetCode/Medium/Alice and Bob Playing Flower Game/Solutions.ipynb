# %% [markdown]
# # **SOLUTION**

# %%
class Solution(object):
    def flowerGame(self, n, m):
        """
        :type n: int
        :type m: int
        :rtype: int
        """
        return n * m // 2

# %% [markdown]
# # **DRAFT**

# %% [markdown]
# # **TESTCASES**

# %%
solution = Solution()

def run_test_case(case_number, input_n, input_m, expected):
    result = solution.flowerGame(input_n, input_m)
    status = "PASSED" if result == expected else "FAILED"
    print(f"Case {case_number} - n: {input_n}, m: {input_m}, Output: {result}, Expected: {expected}, Status: {status}")

test_cases = [
    (1, 3, 2, 3),
    (2, 1, 1, 0),
]

for case_number, input_n, input_m, expected in test_cases:
    run_test_case(case_number, input_n, input_m, expected)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#       8 test_cases = [
#       9     (1, 3, 2, 3),
#      10     (2, 1, 1, 0),
#      11 ]
#      13 for case_number, input_n, input_m, expected in test_cases:
# ---> 14     run_test_case(case_number, input_n, input_m, expected)
#
# Cell In[3], line 4, in run_test_case(case_number, input_n, input_m, expected)
#       3 def run_test_case(case_number, input_n, input_m, expected):
# ----> 4     result = solution.flowerGame(input_mat)
#       5     status = "PASSED" if result == expected else "FAILED"
#       6     print(f"Case {case_number} - n: {input_n}, m: {input_m}, Output: {result}, Expected: {expected}, Status: {status}")
#
# NameError: name 'input_mat' is not defined
